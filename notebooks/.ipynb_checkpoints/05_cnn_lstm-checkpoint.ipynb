# %% [markdown]
# # CNN LSTM

# %%
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../src/')
from cnn_lstm_model import *
from evaluation_metrics import *
from utils import *
from matplotlib import pyplot as plt

# %%
#load processed data
directory = '../data/processed/'
titles = ['EUR_USD','USD_JPY','AUD_USD','GBP_USD','NZD_USD','USD_CAD','USD_CHF']

file_paths = {}
for title in titles:
    file_paths[title] = glob.glob(directory + f'{title.lower()}_*.npy')
# key to train/test set
xy_data = {}
for key, values in file_paths.items():
    s_val = sorted(values) # X_test, X_train, y_test, y_train
    xy_train_test = {}
    xy_train_test['X_test'] = np.load(s_val[0])
    xy_train_test['X_train'] = np.load(s_val[1])
    xy_train_test['y_test'] = np.load(s_val[2])
    xy_train_test['y_train'] = np.load(s_val[3])
    xy_data[key] = xy_train_test

#validation step
for key, val in xy_data.items():
    print(key)
    for x,y in val.items():
        print(f'{x}: {y.shape}')
# Out:
# EUR_USD
# X_test: (14919, 30, 8)
# X_train: (59673, 30, 8)
# y_test: (14919,)
# y_train: (59673,)
# USD_JPY
# X_test: (14919, 30, 8)
# X_train: (59672, 30, 8)
# y_test: (14919,)
# y_train: (59672,)
# AUD_USD
# X_test: (14918, 30, 8)
# X_train: (59668, 30, 8)
# y_test: (14918,)
# y_train: (59668,)
# GBP_USD
# X_test: (14919, 30, 8)
# X_train: (59673, 30, 8)
# y_test: (14919,)
# y_train: (59673,)
# NZD_USD
# X_test: (14922, 30, 8)
# X_train: (59684, 30, 8)
# y_test: (14922,)
# y_train: (59684,)
# USD_CAD
# X_test: (14917, 30, 8)
# X_train: (59668, 30, 8)
# y_test: (14917,)
# y_train: (59668,)
# USD_CHF
# X_test: (14917, 30, 8)
# X_train: (59668, 30, 8)
# y_test: (14917,)
# y_train: (59668,)

# %% [markdown]
# ## Rolling Cross Validation
#
# ### Parameter setup
# |Parameters| Value|
# |----------|------|
# |epochs|50|
# |batch size|128|
# |early stop patience|5|
# |k-fold|5|

# %%
histories = {} #model history
cv_models = {} #trained models
log_loss = {} #mean loss 

#create and train cnn-lstm model for each pair
for count, (key, xy) in enumerate(xy_data.items()) :
    X_train = xy['X_train']
    y_train = xy['y_train']
    timestep = X_train.shape[1]
    features = X_train.shape[2]

    print(f"Training for {key}")
    model = create_cnn_lstm_model(timestep=timestep, features=features)
    history, mean_loss = cross_val(model=model, X=X_train, y=y_train)
    
    histories[key] = history
    cv_models[key] = model
    log_loss[key] = mean_loss
    print(f"Completed training: {count+1}/{len(key)}")
    print("\n")
print("Training complete")
# Out:
# Training for EUR_USD
# Split 1, Train sample 11934, Val sample 11934
# Epoch 1/50
# 94/94 [==============================] - 5s 19ms/step - loss: 0.6999 - accuracy: 0.5047 - val_loss: 0.6932 - val_accuracy: 0.5145
# Epoch 2/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6958 - accuracy: 0.5006 - val_loss: 0.6929 - val_accuracy: 0.5142
# Epoch 3/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6947 - accuracy: 0.4984 - val_loss: 0.6932 - val_accuracy: 0.4940
# Epoch 4/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6940 - accuracy: 0.5041 - val_loss: 0.6931 - val_accuracy: 0.5160
# Epoch 5/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6940 - accuracy: 0.4966 - val_loss: 0.6929 - val_accuracy: 0.5186
# Epoch 6/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6938 - accuracy: 0.5044 - val_loss: 0.6926 - val_accuracy: 0.5215
# Epoch 7/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.
50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5032 - val_loss: 0.6929 - val_accuracy: 0.5132
# Epoch 5/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5091 - val_loss: 0.6929 - val_accuracy: 0.5135
# Epoch 6/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5077 - val_loss: 0.6929 - val_accuracy: 0.5132
# Epoch 7/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6930 - accuracy: 0.5071 - val_loss: 0.6929 - val_accuracy: 0.5124
# Epoch 8/50
# 280/280 [==============================] - 3s 11ms/step - loss: 0.6931 - accuracy: 0.5111 - val_loss: 0.6929 - val_accuracy: 0.5132
# Epoch 9/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6930 - accuracy: 0.5102 - val_loss: 0.6929 - val_accuracy: 0.5110
# 373/373 [==============================] - 1s 2ms/step
# Split 4, Train sample 47736, Val sample 11934
# Epoch 1/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6928 - val_accuracy: 0.5099
# Epoch 2/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6929 - val_accuracy: 0.5099
# Epoch 3/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6930 - accuracy: 0.5077 - val_loss: 0.6929 - val_accuracy: 0.5099
# Epoch 4/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6930 - accuracy: 0.5089 - val_loss: 0.6928 - val_accuracy: 0.5099
# Epoch 5/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6930 - accuracy: 0.5093 - val_loss: 0.6929 - val_accuracy: 0.5099
# Epoch 6/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6930 - accuracy: 0.5119 - val_loss: 0.6929 - val_accuracy: 0.5099
# 373/373 [==============================] - 1s 2ms/step
# Mean Log Loss: 0.6927335167395827
# Completed training: 2/7
#
#
# Training for AUD_USD
# Split 1, Train sample 11933, Val sample 11933
# Epoch 1/50
# 94/94 [==============================] - 3s 19ms/step - loss: 0.6994 - accuracy: 0.5023 - val_loss: 0.6930 - val_accuracy: 0.5081
# Epoch 2/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6956 - accuracy: 0.4964 - val_loss: 0.6932 - val_accuracy: 0.5078
# Epoch 3/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6939 - accuracy: 0.5097 - val_loss: 0.6931 - val_accuracy: 0.5074
# Epoch 4/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6935 - accuracy: 0.5036 - val_loss: 0.6932 - val_accuracy: 0.5035
# Epoch 5/50
# 94/94 [==============================] - 1s 15ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5039
# Epoch 6/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6937 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5072
# 373/373 [==============================] - 1s 3ms/step
# Split 2, Train sample 23866, Val sample 11933
# Epoch 1/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6943 - accuracy: 0.5070 - val_loss: 0.6936 - val_accuracy: 0.4974
# Epoch 2/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6942 - accuracy: 0.4975 - val_loss: 0.6932 - val_accuracy: 0.4964
# Epoch 3/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6934 - accuracy: 0.5022 - val_loss: 0.6931 - val_accuracy: 0.5031
# Epoch 4/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6932 - accuracy: 0.5068 - val_loss: 0.6932 - val_accuracy: 0.4975
# Epoch 5/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6932 - accuracy: 0.5058 - val_loss: 0.6931 - val_accuracy: 0.5008
# Epoch 6/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6933 - accuracy: 0.5026 - val_loss: 0.6931 - val_accuracy: 0.5025
# Epoch 7/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5046
# Epoch 8/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5052
# Epoch 9/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 10/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6933 - accuracy: 0.5012 - val_loss: 0.6931 - val_accuracy: 0.5030
# 373/373 [==============================] - 1s 2ms/step
# Split 3, Train sample 35799, Val sample 11933
# Epoch 1/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6934 - accuracy: 0.5006 - val_loss: 0.6932 - val_accuracy: 0.4941
# Epoch 2/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6933 - accuracy: 0.4975 - val_loss: 0.6932 - val_accuracy: 0.4916
# Epoch 3/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6932 - val_accuracy: 0.5071
# Epoch 4/50
# 280/280 [==============================] - 3s 11ms/step - loss: 0.6933 - accuracy: 0.5014 - val_loss: 0.6931 - val_accuracy: 0.5071
# Epoch 5/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5052 - val_loss: 0.6931 - val_accuracy: 0.5072
# Epoch 6/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5019 - val_loss: 0.6931 - val_accuracy: 0.5082
# Epoch 7/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5018
# Epoch 8/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5070
# Epoch 9/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6931 - val_accuracy: 0.5073
# Epoch 10/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6931 - val_accuracy: 0.5084
# Epoch 11/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.4999 - val_loss: 0.6931 - val_accuracy: 0.5086
# Epoch 12/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5033 - val_loss: 0.6931 - val_accuracy: 0.5087
# Epoch 13/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5088
# Epoch 14/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5002 - val_loss: 0.6931 - val_accuracy: 0.5072
# Epoch 15/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.6931 - val_accuracy: 0.5079
# Epoch 16/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 17/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5010 - val_loss: 0.6931 - val_accuracy: 0.5086
# Epoch 18/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5014 - val_loss: 0.6931 - val_accuracy: 0.5077
# Epoch 19/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5016
# Epoch 20/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5066
# Epoch 21/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5014 - val_loss: 0.6931 - val_accuracy: 0.5088
# Epoch 22/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5062
# Epoch 23/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5043 - val_loss: 0.6931 - val_accuracy: 0.5088
# Epoch 24/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.4983 - val_loss: 0.6931 - val_accuracy: 0.5080
# Epoch 25/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5052 - val_loss: 0.6931 - val_accuracy: 0.5062
# Epoch 26/50
# 280/280 [==============================] - 3s 11ms/step - loss: 0.6931 - accuracy: 0.5045 - val_loss: 0.6931 - val_accuracy: 0.5067
# Epoch 27/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5008 - val_loss: 0.6931 - val_accuracy: 0.5081
# Epoch 28/50
# 280/280 [==============================] - 3s 11ms/step - loss: 0.6932 - accuracy: 0.5040 - val_loss: 0.6931 - val_accuracy: 0.5067
# Epoch 29/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5066
# Epoch 30/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6931 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5062
# Epoch 31/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 32/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5057
# 373/373 [==============================] - 1s 2ms/step
# Split 4, Train sample 47732, Val sample 11933
# Epoch 1/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5037 - val_loss: 0.6931 - val_accuracy: 0.5005
# Epoch 2/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5040 - val_loss: 0.6931 - val_accuracy: 0.5019
# Epoch 3/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5052 - val_loss: 0.6931 - val_accuracy: 0.5044
# Epoch 4/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5055
# Epoch 5/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6932 - accuracy: 0.5052 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 6/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5021
# Epoch 7/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5042 - val_loss: 0.6931 - val_accuracy: 0.5058
# Epoch 8/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5042 - val_loss: 0.6931 - val_accuracy: 0.5052
# Epoch 9/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5024 - val_loss: 0.6931 - val_accuracy: 0.5063
# Epoch 10/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5078 - val_loss: 0.6931 - val_accuracy: 0.5030
# Epoch 11/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6932 - accuracy: 0.5048 - val_loss: 0.6931 - val_accuracy: 0.5015
# Epoch 12/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5014
# Epoch 13/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5030 - val_loss: 0.6931 - val_accuracy: 0.5025
# Epoch 14/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.
- accuracy: 0.5054 - val_loss: 0.6931 - val_accuracy: 0.5056
# 373/373 [==============================] - 1s 2ms/step
# Mean Log Loss: 0.6930827836188218
# Completed training: 6/7
#
#
# Training for USD_CHF
# Split 1, Train sample 11933, Val sample 11933
# Epoch 1/50
# 94/94 [==============================] - 3s 19ms/step - loss: 0.6968 - accuracy: 0.4962 - val_loss: 0.6928 - val_accuracy: 0.5108
# Epoch 2/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6951 - accuracy: 0.5023 - val_loss: 0.6930 - val_accuracy: 0.5067
# Epoch 3/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6940 - accuracy: 0.5046 - val_loss: 0.6929 - val_accuracy: 0.5134
# Epoch 4/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6941 - accuracy: 0.5055 - val_loss: 0.6929 - val_accuracy: 0.5137
# Epoch 5/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6944 - accuracy: 0.4964 - val_loss: 0.6929 - val_accuracy: 0.5142
# Epoch 6/50
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6938 - accuracy: 0.5071 - val_loss: 0.6930 - val_accuracy: 0.5084
# 373/373 [==============================] - 1s 2ms/step
# Split 2, Train sample 23866, Val sample 11933
# Epoch 1/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6946 - accuracy: 0.5036 - val_loss: 0.6936 - val_accuracy: 0.4970
# Epoch 2/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6939 - accuracy: 0.5065 - val_loss: 0.6933 - val_accuracy: 0.5039
# Epoch 3/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6936 - accuracy: 0.5070 - val_loss: 0.6932 - val_accuracy: 0.5012
# Epoch 4/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6936 - accuracy: 0.5077 - val_loss: 0.6934 - val_accuracy: 0.4982
# Epoch 5/50
# 187/187 [==============================] - 2s 12ms/step - loss: 0.6934 - accuracy: 0.5061 - val_loss: 0.6930 - val_accuracy: 0.5170
# Epoch 6/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6931 - accuracy: 0.5117 - val_loss: 0.6930 - val_accuracy: 0.5146
# Epoch 7/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6936 - accuracy: 0.5035 - val_loss: 0.6934 - val_accuracy: 0.4979
# Epoch 8/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6934 - accuracy: 0.5075 - val_loss: 0.6932 - val_accuracy: 0.5026
# Epoch 9/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6930 - accuracy: 0.5074 - val_loss: 0.6932 - val_accuracy: 0.5031
# Epoch 10/50
# 187/187 [==============================] - 2s 13ms/step - loss: 0.6931 - accuracy: 0.5112 - val_loss: 0.6935 - val_accuracy: 0.4989
# 373/373 [==============================] - 1s 2ms/step
# Split 3, Train sample 35799, Val sample 11933
# Epoch 1/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6933 - accuracy: 0.5090 - val_loss: 0.6936 - val_accuracy: 0.5078
# Epoch 2/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5099 - val_loss: 0.6935 - val_accuracy: 0.5074
# Epoch 3/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6930 - accuracy: 0.5100 - val_loss: 0.6935 - val_accuracy: 0.5066
# Epoch 4/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5100 - val_loss: 0.6935 - val_accuracy: 0.5065
# Epoch 5/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5070 - val_loss: 0.6936 - val_accuracy: 0.5079
# Epoch 6/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6932 - accuracy: 0.5069 - val_loss: 0.6937 - val_accuracy: 0.5052
# Epoch 7/50
# 280/280 [==============================] - 3s 12ms/step - loss: 0.6930 - accuracy: 0.5122 - val_loss: 0.6936 - val_accuracy: 0.5076
# Epoch 8/50
# 280/280 [==============================] - 4s 13ms/step - loss: 0.6932 - accuracy: 0.5079 - val_loss: 0.6936 - val_accuracy: 0.5056
# 373/373 [==============================] - 1s 2ms/step
# Split 4, Train sample 47732, Val sample 11933
# Epoch 1/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6932 - accuracy: 0.5092 - val_loss: 0.6931 - val_accuracy: 0.5074
# Epoch 2/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6932 - accuracy: 0.5061 - val_loss: 0.6931 - val_accuracy: 0.5069
# Epoch 3/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5064 - val_loss: 0.6931 - val_accuracy: 0.5093
# Epoch 4/50
# 373/373 [==============================] - 5s 12ms/step - loss: 0.6932 - accuracy: 0.5070 - val_loss: 0.6931 - val_accuracy: 0.5077
# Epoch 5/50
# 373/373 [==============================] - 4s 12ms/step - loss: 0.6931 - accuracy: 0.5081 - val_loss: 0.6931 - val_accuracy: 0.5073
# Epoch 6/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6932 - accuracy: 0.5091 - val_loss: 0.6931 - val_accuracy: 0.5075
# Epoch 7/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5079 - val_loss: 0.6932 - val_accuracy: 0.5062
# Epoch 8/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6932 - accuracy: 0.5043 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 9/50
# 373/373 [==============================] - 4s 11ms/step - loss: 0.6931 - accuracy: 0.5096 - val_loss: 0.6931 - val_accuracy: 0.5015
# 373/373 [==============================] - 1s 2ms/step
# Mean Log Loss: 0.693000855378035
# Completed training: 7/7
#
#
# Training complete

# %% [markdown]
# # Cross Validation Evaluation

# %% [markdown]
# ### Accuracy score over splits
# -  A high accuracy with low variance across splits indicates good generalization
# -  High variability indicates high dependence on specific training data, likely due to noise

# %%
plt.figure(figsize=(16, 12))

for pos, (title, history_list) in enumerate(histories.items()):
    accuracy = []
    val_accuracy = []
    for history in history_list:
        accuracy.extend(history.history['accuracy'])
        val_accuracy.extend(history.history['val_accuracy'])
    plt.subplot(4,2,pos+1)
    plt.plot(accuracy, color='orange',label='train' )
    plt.plot(val_accuracy, color='purple', label='val' )
    plt.title(title)
    plt.legend()
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean accuracy

# %%
plt.figure(figsize=(7, 6))

splits = []
mean_train_acc = []
mean_val_acc = []



for pos, (title, history_list) in enumerate(histories.items()):
    count = len(history_list)
    for history in history_list:
        splits.append([history.history['accuracy'][-1], history.history['val_accuracy'][-1]])

for i in range(0,count):
    sum_val = 0
    sum_train = 0
    for j in range(i,(count*len(title)),4): #acc,val for each split 1-4
        sum_train = sum_train + splits[j][0]
        sum_val = sum_val + splits[j][1]
    mean_sum_val = sum_val/len(title)
    mean_sum_train = sum_train/len(title)
    print(f'split{i+1} mean train, val: {mean_sum_train}, {mean_sum_val}')
    mean_train_acc.append(mean_sum_train)
    mean_val_acc.append(mean_sum_val)
    
plt.plot(mean_train_acc, label='val', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='white')
plt.plot(mean_val_acc, label='train', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='blue')
plt.xlabel('Split')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# split1 mean train, val: 0.5053329638072422, 0.5091633456093925
# split2 mean train, val: 0.5071583901132856, 0.5067093329770225
# split3 mean train, val: 0.5078906076295036, 0.5077029636928013
# split4 mean train, val: 0.5083433900560651, 0.5050216913223267

# %% [markdown]
# ### Mean Loss
# optimized to achieve lowest value

# %%
np.mean(np.array(list(log_loss.values())))
# Out:
# 0.6929085901641523

# %%
plt.figure(figsize=(7, 6))

splits = []
mean_train_acc = []
mean_val_acc = []



for pos, (title, history_list) in enumerate(histories.items()):
    count = len(history_list)
    for history in history_list:
        splits.append([history.history['loss'][-1], history.history['val_loss'][-1]])

for i in range(0,count):
    sum_val = 0
    sum_train = 0
    for j in range(i,(count*len(title)),4): #acc,val for each split 1-4
        sum_train = sum_train + splits[j][0]
        sum_val = sum_val + splits[j][1]
    mean_sum_val = sum_val/len(title)
    mean_sum_train = sum_train/len(title)
    print(f'split{i+1} mean train, val: {mean_sum_train}, {mean_sum_val}')
    mean_train_acc.append(mean_sum_train)
    mean_val_acc.append(mean_sum_val)
    
plt.plot(mean_train_acc, label='val', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='white')
plt.plot(mean_val_acc, label='train', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='blue')
plt.xlabel('Split')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# split1 mean train, val: 0.6934574672154018, 0.6930560043879918
# split2 mean train, val: 0.6931541647229876, 0.69309891973223
# split3 mean train, val: 0.6930957521711077, 0.6931264655930656
# split4 mean train, val: 0.6930737495422363, 0.6930598105703082

# %% [markdown]
# ## Loss analysis
#
# Detects for overfitting and underfitting
# - Overfitting: Train loss is significantly lower than validation loss
# - Underfitting: Train loss and validation loss is both high
# - Ideal: Train loss and val loss are equally low

# %%
#learning curve 

plt.figure(figsize=(16, 12))

for pos, (title, history_list) in enumerate(histories.items()):
    train_losses = []
    val_losses = []
    for history in history_list:
        train_losses.extend(history.history['loss'])
        val_losses.extend(history.history['val_loss'])
    plt.subplot(4,2,pos+1)
    plt.plot(train_losses, label='train loss', color='red')
    plt.plot(val_losses, label='val loss', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.grid(axis='x', linestyle='--')
    plt.title(title)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Summary

# %%
cv_models['EUR_USD'].summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 6, 32)        128
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 4, 64)        6208
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 2, 64)        0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 128)          0
#  tributed)
#
#  lstm (LSTM)                 (None, 64)                49408
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 16)                1040
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 56,801
# Trainable params: 56,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
models = {}
for (key, model), xy in zip(cv_models.items(), xy_data.values()):
    history = train_model(model, xy['X_train'], xy['y_train'])
    models[key] = model
# Out:
# Epoch 1/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5096
# Epoch 2/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5096
# Epoch 3/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5133
# Epoch 4/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5092
# Epoch 5/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5133
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6929 - accuracy: 0.5103
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5105
# Epoch 8/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5094
# Epoch 1/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5077
# Epoch 2/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5095
# Epoch 3/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5088
# Epoch 4/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5081
# Epoch 5/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6929 - accuracy: 0.5097
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5090
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5087
# Epoch 8/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6929 - accuracy: 0.5112
# Epoch 9/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6929 - accuracy: 0.5095
# Epoch 10/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6930 - accuracy: 0.5076
# Epoch 11/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6929 - accuracy: 0.5086
# Epoch 12/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6929 - accuracy: 0.5098
# Epoch 13/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6929 - accuracy: 0.5109
# Epoch 1/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6931 - accuracy: 0.5032
# Epoch 2/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6931 - accuracy: 0.5049
# Epoch 3/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6931 - accuracy: 0.5013
# Epoch 4/50
# 467/467 [==============================] - 5s 10ms/step - loss: 0.6931 - accuracy: 0.5038
# Epoch 5/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5052
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5032
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5047
# Epoch 8/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5039
# Epoch 9/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5035
# Epoch 10/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5022
# Epoch 1/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 2/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5069
# Epoch 3/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5058
# Epoch 4/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 5/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5061
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5090
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 8/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 9/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5095
# Epoch 10/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5074
# Epoch 11/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5069
# Epoch 12/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5061
# Epoch 13/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 14/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 1/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 2/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5062
# Epoch 3/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 4/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5099
# Epoch 5/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5096
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5081
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5099
# Epoch 8/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 9/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6930 - accuracy: 0.5108
# Epoch 10/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5105
# Epoch 11/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 12/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5087
# Epoch 13/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 14/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 1/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5043
# Epoch 2/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5027
# Epoch 3/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5046
# Epoch 4/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5034
# Epoch 5/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5030
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5060
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5049
# Epoch 8/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5047
# Epoch 9/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6932 - accuracy: 0.5043
# Epoch 10/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 11/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5050
# Epoch 1/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5055
# Epoch 2/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5066
# Epoch 3/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5043
# Epoch 4/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6934 - accuracy: 0.5032
# Epoch 5/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 6/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5058
# Epoch 7/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5082
# Epoch 8/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6932 - accuracy: 0.5068
# Epoch 9/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5082
# Epoch 10/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5057
# Epoch 11/50
# 467/467 [==============================] - 6s 12ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 12/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 13/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5069
# Epoch 14/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6932 - accuracy: 0.5064
# Epoch 15/50
# 467/467 [==============================] - 5s 11ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 16/50
# 467/467 [==============================] - 5s 12ms/step - loss: 0.6931 - accuracy: 0.5076

# %% [markdown]
# ### Generate test prediction

# %%
threshold = 0.5
y_pred_dict = {}
y_pred_dict_prob = {}
for (key, model), xy in zip(models.items(), xy_data.values() ):
    y_pred = model.predict(xy['X_test'])
    y_pred_dict_prob[key] = y_pred
    y_pred_binary = (y_pred >= threshold).astype(int)
    y_pred_binary = y_pred_binary.flatten() #Convert to 1D
    y_pred_dict[key] = y_pred_binary
    print(key)
    print(np.bincount(y_train))  # Count occurrences of each class in the training set
    print(np.bincount(xy['y_test']))   # testing set
    print(np.bincount(y_pred_binary)) # prediction set
    print(len(xy['y_test'])-len(y_pred_binary))
    print(len)
# Out:
# 467/467 [==============================] - 1s 3ms/step
# EUR_USD
# [30040 29628]
# [7506 7413]
# [11565  3354]
# 0
# <built-in function len>
# 467/467 [==============================] - 1s 2ms/step
# USD_JPY
# [30040 29628]
# [7340 7579]
# [    0 14919]
# 0
# <built-in function len>
# 467/467 [==============================] - 1s 2ms/step
# AUD_USD
# [30040 29628]
# [7516 7402]
# [13897  1021]
# 0
# <built-in function len>
# 467/467 [==============================] - 1s 2ms/step
# GBP_USD
# [30040 29628]
# [7471 7448]
# [14497   422]
# 0
# <built-in function len>
# 467/467 [==============================] - 1s 3ms/step
# NZD_USD
# [30040 29628]
# [7628 7294]
# [11574  3348]
# 0
# <built-in function len>
# 467/467 [==============================] - 1s 2ms/step
# USD_CAD
# [30040 29628]
# [7560 7357]
# [14832    85]
# 0
# <built-in function len>
# 467/467 [==============================] - 1s 2ms/step
# USD_CHF
# [30040 29628]
# [7507 7410]
# [11627  3290]
# 0
# <built-in function len>

# %% [markdown]
# #### Visualization of y_test and y_pred

# %%
for pos, ((key, y_pred), xy) in enumerate(zip(y_pred_dict.items(),xy_data.values())):  
    step = 100 
    y_test_ds = xy['y_test'][::step] #downsampled to 100 steps
    y_pred_ds = y_pred[::step]

    #plt.subplot(7,1,pos+1)
    plt.figure(figsize=(10,3))
    plt.plot(y_test_ds, color = "green", label = "Test")
    plt.plot(y_pred_ds, color = "blue", label = "Pred")
    plt.title(key)
    plt.tight_layout()
    plt.legend()

plt.show()

# %%
plt.figure(figsize=(14, 16))

for pos, ((key, y_pred), xy) in enumerate (zip(y_pred_dict.items(), xy_data.values())):
    test_counts = np.bincount(xy['y_test'])
    pred_counts = np.bincount(y_pred)

    # Plotting histograms using plt directly
    plt.subplot(4,2,pos+1)
    # Plot test data histogram
    plt.hist(xy['y_test'], bins=[-0.5, 0.5, 1.5], alpha=0.5, color='green', label='Test')

    # Plot pred data histogram
    plt.hist(y_pred, bins=[-0.5, 0.5, 1.5], alpha=0.5, color='blue', label='Pred')

    # Customize plot
    plt.xticks([0, 1], ['0', '1'])
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title(f'Comparison of 0s and 1s between Test and Pred for {key}')
    plt.tight_layout()
    plt.legend()
    

plt.show()

# %% [markdown]
# ## Metrics
#
# Evaluate performance with accuracy, f1_score, precision and recall

# %%
metrics_dict = {}

for xy, (key, y_pred) in zip(xy_data.values(), y_pred_dict.items()):
    
    metrics = calculate_metrics(xy['y_test'], y_pred)
    metrics_dict[key] = metrics
    print(f"{key}: ", metrics)
# Out:
# EUR_USD:  {'accuracy': 0.5131711240699779, 'f1_score': 0.32543884090275843, 'precision': 0.5223613595706619, 'recall': 0.23634156212059895}
# USD_JPY:  {'accuracy': 0.5080099202359407, 'f1_score': 0.6737487776691261, 'precision': 0.5080099202359407, 'recall': 1.0}
# AUD_USD:  {'accuracy': 0.5079099074943022, 'f1_score': 0.12845779413510625, 'precision': 0.5298726738491675, 'recall': 0.0730883544987841}
# GBP_USD:  {'accuracy': 0.5026476305382398, 'f1_score': 0.05717916137229987, 'precision': 0.533175355450237, 'recall': 0.030209452201933405}
# NZD_USD:  {'accuracy': 0.5180270741187508, 'f1_score': 0.3241871828603646, 'precision': 0.5152329749103942, 'recall': 0.2364957499314505}
# USD_CAD:  {'accuracy': 0.5062009787490782, 'f1_score': 0.010212308519215264, 'precision': 0.4470588235294118, 'recall': 0.005165148837841511}
# USD_CHF:  {'accuracy': 0.5127706643426962, 'f1_score': 0.3207476635514019, 'precision': 0.521580547112462, 'recall': 0.23157894736842105}

# %% [markdown]
# ##### Metric Bar Chart

# %%
all_metrics = list(next(iter(metrics_dict.values())).keys())

num_models = len(metrics_dict)
bar_width = 0.12
index = np.arange(len(all_metrics))

plt.figure(figsize=(15, 6))
colors = plt.get_cmap('tab20b').colors

for i, (key, metrics) in enumerate(metrics_dict.items()):
    values = [metrics[metric] for metric in all_metrics]
    plt.bar(index + i * bar_width, values, bar_width, label=key, color=colors[i])
    
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Model Performance Metrics Comparison')
plt.xticks(index + bar_width * (num_models - 1) / 2, all_metrics)
plt.ylim(0, 1.0)
plt.legend()
plt.grid(True, axis='y', linestyle='--', linewidth=0.35, color='black')

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
y_probs = xy_data.items()
y_pred_dict_prob

plt.figure(figsize=(8, 6))
for i, ((key, xy), y_prob) in enumerate(zip(xy_data.items(), y_pred_dict_prob.values())):
    fpr, tpr, thresholds = roc_curve(xy['y_test'], y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=colors[i], lw=0.8, label=f'{key} (AUC = {roc_auc:.3f})')
    plt.plot([0, 1], [0, 1], color='red', linestyle='--', linewidth=0.25)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
plt.show()

# %% [markdown]
# ##### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

for (title, y_pred), xy in zip(y_pred_dict.items(), xy_data.values()):
    print(title)
    cm = confusion_matrix(xy['y_test'], y_pred)
    tn, fp, fn, tp = cm.ravel()
    print(f'True Negatives: {tn}, False Positives: {fp}, False Negatives: {fn}, True Positives: {tp}')
# Out:
# EUR_USD
# True Negatives: 5904, False Positives: 1602, False Negatives: 5661, True Positives: 1752
# USD_JPY
# True Negatives: 0, False Positives: 7340, False Negatives: 0, True Positives: 7579
# AUD_USD
# True Negatives: 7036, False Positives: 480, False Negatives: 6861, True Positives: 541
# GBP_USD
# True Negatives: 7274, False Positives: 197, False Negatives: 7223, True Positives: 225
# NZD_USD
# True Negatives: 6005, False Positives: 1623, False Negatives: 5569, True Positives: 1725
# USD_CAD
# True Negatives: 7513, False Positives: 47, False Negatives: 7319, True Positives: 38
# USD_CHF
# True Negatives: 5933, False Positives: 1574, False Negatives: 5694, True Positives: 1716

# %% [markdown]
# ## Save results

# %%
#Save results to csv
model_type = 'CNN-LSTM'

for key, metrics in metrics_dict.items():
    metrics_df = pd.DataFrame([metrics])
    save_metrics_to_csv(metrics_df, model_type, f'{key}')

# %% [markdown]
# End of section
