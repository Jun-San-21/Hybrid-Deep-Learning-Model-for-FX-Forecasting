# %% [markdown]
# # CNN RNN

# %%
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../src/')
from cnn_srnn_model import *
from evaluation_metrics import *
from utils import *
from matplotlib import pyplot as plt

# %%
#load processed data
directory = '../data/processed/'
titles = ['EUR_USD','USD_JPY','AUD_USD','GBP_USD','NZD_USD','USD_CAD','USD_CHF']

file_paths = {}
for title in titles:
    file_paths[title] = glob.glob(directory + f'{title.lower()}_*.npy')
# key to train/test set
xy_data = {}
for key, values in file_paths.items():
    s_val = sorted(values) # X_test, X_train, y_test, y_train
    xy_train_test = {}
    xy_train_test['X_test'] = np.load(s_val[0])
    xy_train_test['X_train'] = np.load(s_val[1])
    xy_train_test['y_test'] = np.load(s_val[2])
    xy_train_test['y_train'] = np.load(s_val[3])
    xy_data[key] = xy_train_test

#validation step
for key, val in xy_data.items():
    print(key)
    for x,y in val.items():
        print(f'{x}: {y.shape}')
# Out:
# EUR_USD
# X_test: (14919, 30, 8)
# X_train: (59673, 30, 8)
# y_test: (14919,)
# y_train: (59673,)
# USD_JPY
# X_test: (14919, 30, 8)
# X_train: (59672, 30, 8)
# y_test: (14919,)
# y_train: (59672,)
# AUD_USD
# X_test: (14918, 30, 8)
# X_train: (59668, 30, 8)
# y_test: (14918,)
# y_train: (59668,)
# GBP_USD
# X_test: (14919, 30, 8)
# X_train: (59673, 30, 8)
# y_test: (14919,)
# y_train: (59673,)
# NZD_USD
# X_test: (14922, 30, 8)
# X_train: (59684, 30, 8)
# y_test: (14922,)
# y_train: (59684,)
# USD_CAD
# X_test: (14917, 30, 8)
# X_train: (59668, 30, 8)
# y_test: (14917,)
# y_train: (59668,)
# USD_CHF
# X_test: (14917, 30, 8)
# X_train: (59668, 30, 8)
# y_test: (14917,)
# y_train: (59668,)

# %% [markdown]
# ## Rolling cross validation
#
# ### Parameter setup
# |Parameters| Value|
# |----------|------|
# |epochs|50|
# |batch size|128|
# |early stop patience|5|
# |k-fold|5|

# %%
histories = {} #model history
cv_models = {} #trained models
log_loss = {} #mean loss 

#create and train cnn-lstm model for each pair
for count, (key, xy) in enumerate(xy_data.items()) :
    X_train = xy['X_train']
    y_train = xy['y_train']
    timestep = X_train.shape[1]
    features = X_train.shape[2]

    print(f"Training for {key}")
    model = create_cnn_srnn_model(timestep=timestep, features=features)
    history, mean_loss = cross_val(model=model, X=X_train, y=y_train)
    
    histories[key] = history
    cv_models[key] = model
    log_loss[key] = mean_loss
    print(f"Completed training: {count+1}/{len(key)}")
    print("\n")
print("Training complete")
# Out:
# Training for EUR_USD
# Split 1, Train sample 11934, Val sample 11934
# Epoch 1/50
# 94/94 [==============================] - 11s 56ms/step - loss: 0.7192 - accuracy: 0.4959 - val_loss: 0.6949 - val_accuracy: 0.5184
# Epoch 2/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.6990 - accuracy: 0.4944 - val_loss: 0.6933 - val_accuracy: 0.4858
# Epoch 3/50
# 94/94 [==============================] - 5s 49ms/step - loss: 0.6946 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.4855
# Epoch 4/50
# 94/94 [==============================] - 4s 46ms/step - loss: 0.6944 - accuracy: 0.4885 - val_loss: 0.6931 - val_accuracy: 0.4855
# Epoch 5/50
# 94/94 [==============================] - 4s 46ms/step - loss: 0.
ms/step - loss: 0.6932 - accuracy: 0.5043 - val_loss: 0.6931 - val_accuracy: 0.5023
# Epoch 8/50
# 280/280 [==============================] - 12s 43ms/step - loss: 0.6933 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5020
# Epoch 9/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.6933 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5020
# Epoch 10/50
# 280/280 [==============================] - 12s 44ms/step - loss: 0.6933 - accuracy: 0.5035 - val_loss: 0.6931 - val_accuracy: 0.5021
# Epoch 11/50
# 280/280 [==============================] - 12s 42ms/step - loss: 0.6931 - accuracy: 0.5046 - val_loss: 0.6931 - val_accuracy: 0.5021
# Epoch 12/50
# 280/280 [==============================] - 12s 42ms/step - loss: 0.6932 - accuracy: 0.5052 - val_loss: 0.6931 - val_accuracy: 0.5021
# 373/373 [==============================] - 2s 6ms/step
# Split 4, Train sample 47732, Val sample 11933
# Epoch 1/50
# 373/373 [==============================] - 16s 43ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5030
# Epoch 2/50
# 373/373 [==============================] - 16s 42ms/step - loss: 0.6932 - accuracy: 0.5028 - val_loss: 0.6931 - val_accuracy: 0.5030
# Epoch 3/50
# 373/373 [==============================] - 16s 43ms/step - loss: 0.6932 - accuracy: 0.5043 - val_loss: 0.6931 - val_accuracy: 0.5029
# Epoch 4/50
# 373/373 [==============================] - 16s 43ms/step - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5030
# Epoch 5/50
# 373/373 [==============================] - 15s 40ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6932 - val_accuracy: 0.5030
# Epoch 6/50
# 373/373 [==============================] - 17s 44ms/step - loss: 0.6932 - accuracy: 0.5037 - val_loss: 0.6932 - val_accuracy: 0.5030
# Epoch 7/50
# 373/373 [==============================] - 15s 40ms/step - loss: 0.6931 - accuracy: 0.5033 - val_loss: 0.6932 - val_accuracy: 0.5030
# Epoch 8/50
# 373/373 [==============================] - 15s 40ms/step - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5030
# 373/373 [==============================] - 2s 6ms/step
# Mean Log Loss: 0.6930546563452074
# Completed training: 7/7
#
#
# Training complete

# %% [markdown]
# # Cross Validation Evaluation

# %% [markdown]
# ### Accuracy score over splits
# -  A high accuracy with low variance across splits indicates good generalization
# -  High variability indicates high dependence on specific training data, likely due to noise

# %%
plt.figure(figsize=(16, 12))

for pos, (title, history_list) in enumerate(histories.items()):
    accuracy = []
    val_accuracy = []
    for history in history_list:
        accuracy.extend(history.history['accuracy'])
        val_accuracy.extend(history.history['val_accuracy'])
    plt.subplot(4,2,pos+1)
    plt.plot(accuracy, color='orange',label='train' )
    plt.plot(val_accuracy, color='purple', label='val' )
    plt.title(title)
    plt.legend()
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Accuracy

# %%
plt.figure(figsize=(7, 6))

splits = []
mean_train_acc = []
mean_val_acc = []



for pos, (title, history_list) in enumerate(histories.items()):
    count = len(history_list)
    for history in history_list:
        splits.append([history.history['accuracy'][-1], history.history['val_accuracy'][-1]])

for i in range(0,count):
    sum_val = 0
    sum_train = 0
    for j in range(i,(count*len(title)),4): #acc,val for each split 1-4
        sum_train = sum_train + splits[j][0]
        sum_val = sum_val + splits[j][1]
    mean_sum_val = sum_val/len(title)
    mean_sum_train = sum_train/len(title)
    print(f'split{i+1} mean train, val: {mean_sum_train}, {mean_sum_val}')
    mean_train_acc.append(mean_sum_train)
    mean_val_acc.append(mean_sum_val)
    
plt.plot(mean_train_acc, label='val', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='white')
plt.plot(mean_val_acc, label='train', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='blue')
plt.xlabel('Split')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# split1 mean train, val: 0.5072365147726876, 0.5053804474217551
# split2 mean train, val: 0.5065898724964687, 0.5068528567041669
# split3 mean train, val: 0.5079744373049054, 0.507834621838161
# split4 mean train, val: 0.506906943661826, 0.5032499773161752

# %% [markdown]
# ### Mean Loss
# optimized to achieve lowest value

# %%
np.mean(np.array(list(log_loss.values())))
# Out:
# 0.6930284386269204

# %%
plt.figure(figsize=(7, 6))

splits = []
mean_train_acc = []
mean_val_acc = []



for pos, (title, history_list) in enumerate(histories.items()):
    count = len(history_list)
    for history in history_list:
        splits.append([history.history['loss'][-1], history.history['val_loss'][-1]])

for i in range(0,count):
    sum_val = 0
    sum_train = 0
    for j in range(i,(count*len(title)),4): #acc,val for each split 1-4
        sum_train = sum_train + splits[j][0]
        sum_val = sum_val + splits[j][1]
    mean_sum_val = sum_val/len(title)
    mean_sum_train = sum_train/len(title)
    print(f'split{i+1} mean train, val: {mean_sum_train}, {mean_sum_val}')
    mean_train_acc.append(mean_sum_train)
    mean_val_acc.append(mean_sum_val)
    
plt.plot(mean_train_acc, label='val', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='white')
plt.plot(mean_val_acc, label='train', color='b', marker='.', linestyle='solid', markersize=24, markerfacecolor='blue')
plt.xlabel('Split')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# split1 mean train, val: 0.6934157695089068, 0.6931333201272147
# split2 mean train, val: 0.693222565310342, 0.6930760996682304
# split3 mean train, val: 0.6930682744298663, 0.6930703946522304
# split4 mean train, val: 0.6930787222726005, 0.6931648254394531

# %% [markdown]
# ## Loss analysis
#
# Detects for overfitting and underfitting
# - Overfitting: Train loss is significantly lower than validation loss
# - Underfitting: Train loss and validation loss is both high
# - Ideal: Train loss and val loss are equally low

# %%
#learning curve 

plt.figure(figsize=(16, 12))

for pos, (title, history_list) in enumerate(histories.items()):
    train_losses = []
    val_losses = []
    for history in history_list:
        train_losses.extend(history.history['loss'])
        val_losses.extend(history.history['val_loss'])
    plt.subplot(4,2,pos+1)
    plt.plot(train_losses, label='train loss', color='red')
    plt.plot(val_losses, label='val loss', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.grid(axis='x', linestyle='--')
    plt.title(title)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Summary

# %%
cv_models['EUR_USD'].summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 6, 32)        128
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 4, 64)        6208
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 2, 64)        0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 128)          0
#  tributed)
#
#  simple_rnn (SimpleRNN)      (None, 64)                12352
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 16)                1040
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 19,745
# Trainable params: 19,745
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
models = {}
for (key, model), xy in zip(cv_models.items(), xy_data.values()):
    history = train_model(model, xy['X_train'], xy['y_train'])
    models[key] = model
# Out:
# Epoch 1/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6932 - accuracy: 0.5079
# Epoch 2/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5093
# Epoch 3/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6932 - accuracy: 0.5085
# Epoch 4/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 5/50
# 467/467 [==============================] - 20s 42ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 6/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6930 - accuracy: 0.5078
# Epoch 7/50
# 467/467 [==============================] - 19s 41ms/step - loss: 0.6931 - accuracy: 0.5090
# Epoch 1/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5092
# Epoch 2/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6931 - accuracy: 0.5093
# Epoch 3/50
# 467/467 [==============================] - 20s 43ms/step - loss: 0.6930 - accuracy: 0.5095
# Epoch 4/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5092
# Epoch 5/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6930 - accuracy: 0.5091
# Epoch 6/50
# 467/467 [==============================] - 18s 40ms/step - loss: 0.6931 - accuracy: 0.5094
# Epoch 7/50
# 467/467 [==============================] - 20s 42ms/step - loss: 0.6931 - accuracy: 0.5093
# Epoch 8/50
# 467/467 [==============================] - 19s 42ms/step - loss: 0.6931 - accuracy: 0.5093
# Epoch 1/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6932 - accuracy: 0.5031
# Epoch 2/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6932 - accuracy: 0.5029
# Epoch 3/50
# 467/467 [==============================] - 20s 43ms/step - loss: 0.6932 - accuracy: 0.5031
# Epoch 4/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6932 - accuracy: 0.5027
# Epoch 5/50
# 467/467 [==============================] - 17s 35ms/step - loss: 0.6932 - accuracy: 0.5024
# Epoch 6/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6932 - accuracy: 0.5031
# Epoch 7/50
# 467/467 [==============================] - 19s 41ms/step - loss: 0.6932 - accuracy: 0.5045
# Epoch 8/50
# 467/467 [==============================] - 19s 41ms/step - loss: 0.6932 - accuracy: 0.5018
# Epoch 9/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6931 - accuracy: 0.5032
# Epoch 10/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6931 - accuracy: 0.5030
# Epoch 11/50
# 467/467 [==============================] - 20s 42ms/step - loss: 0.6931 - accuracy: 0.5031
# Epoch 12/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6932 - accuracy: 0.5032
# Epoch 1/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 2/50
# 467/467 [==============================] - 17s 36ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 3/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 4/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5046
# Epoch 5/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 6/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5074
# Epoch 7/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 8/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 9/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6930 - accuracy: 0.5063
# Epoch 10/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5077
# Epoch 11/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 12/50
# 467/467 [==============================] - 18s 40ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 13/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6930 - accuracy: 0.5075
# Epoch 14/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6930 - accuracy: 0.5086
# Epoch 15/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 16/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 17/50
# 467/467 [==============================] - 19s 41ms/step - loss: 0.6930 - accuracy: 0.5080
# Epoch 1/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6930 - accuracy: 0.5069
# Epoch 2/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 3/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6930 - accuracy: 0.5101
# Epoch 4/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6930 - accuracy: 0.5101
# Epoch 5/50
# 467/467 [==============================] - 19s 41ms/step - loss: 0.6930 - accuracy: 0.5098
# Epoch 6/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6930 - accuracy: 0.5097
# Epoch 7/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6930 - accuracy: 0.5088
# Epoch 8/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6931 - accuracy: 0.5085
# Epoch 1/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6932 - accuracy: 0.5061
# Epoch 2/50
# 467/467 [==============================] - 20s 43ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 3/50
# 467/467 [==============================] - 20s 42ms/step - loss: 0.6932 - accuracy: 0.5047
# Epoch 4/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5055
# Epoch 5/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6931 - accuracy: 0.5047
# Epoch 6/50
# 467/467 [==============================] - 19s 42ms/step - loss: 0.6931 - accuracy: 0.5056
# Epoch 1/50
# 467/467 [==============================] - 19s 41ms/step - loss: 0.6931 - accuracy: 0.5030
# Epoch 2/50
# 467/467 [==============================] - 19s 42ms/step - loss: 0.6931 - accuracy: 0.5037
# Epoch 3/50
# 467/467 [==============================] - 18s 38ms/step - loss: 0.6932 - accuracy: 0.5038
# Epoch 4/50
# 467/467 [==============================] - 17s 37ms/step - loss: 0.6932 - accuracy: 0.5029
# Epoch 5/50
# 467/467 [==============================] - 19s 40ms/step - loss: 0.6932 - accuracy: 0.5030
# Epoch 6/50
# 467/467 [==============================] - 20s 43ms/step - loss: 0.6931 - accuracy: 0.5036
# Epoch 7/50
# 467/467 [==============================] - 20s 42ms/step - loss: 0.6932 - accuracy: 0.5030
# Epoch 8/50
# 467/467 [==============================] - 18s 39ms/step - loss: 0.6931 - accuracy: 0.5036

# %% [markdown]
# ### Generate test prediction

# %%
threshold = 0.5
y_pred_dict = {}
y_pred_dict_prob = {}
for (key, model), xy in zip(models.items(), xy_data.values() ):
    y_pred = model.predict(xy['X_test'])
    y_pred_dict_prob[key] = y_pred
    y_pred_binary = (y_pred >= threshold).astype(int)
    y_pred_binary = y_pred_binary.flatten() #Convert to 1D
    y_pred_dict[key] = y_pred_binary
    print(key)
    print(np.bincount(y_train))  # Count occurrences of each class in the training set
    print(np.bincount(xy['y_test']))   # testing set
    print(np.bincount(y_pred_binary)) # prediction set
    print(len(xy['y_test'])-len(y_pred_binary))
    print(len)
# Out:
# 467/467 [==============================] - 3s 6ms/step
# EUR_USD
# [30040 29628]
# [7506 7413]
# [14531   388]
# 0
# <built-in function len>
# 467/467 [==============================] - 3s 6ms/step
# USD_JPY
# [30040 29628]
# [7340 7579]
# [    2 14917]
# 0
# <built-in function len>
# 467/467 [==============================] - 3s 6ms/step
# AUD_USD
# [30040 29628]
# [7516 7402]
# [14894    24]
# 0
# <built-in function len>
# 467/467 [==============================] - 3s 6ms/step
# GBP_USD
# [30040 29628]
# [7471 7448]
# [13901  1018]
# 0
# <built-in function len>
# 467/467 [==============================] - 3s 6ms/step
# NZD_USD
# [30040 29628]
# [7628 7294]
# [14262   660]
# 0
# <built-in function len>
# 467/467 [==============================] - 3s 6ms/step
# USD_CAD
# [30040 29628]
# [7560 7357]
# [14906    11]
# 0
# <built-in function len>
# 467/467 [==============================] - 3s 6ms/step
# USD_CHF
# [30040 29628]
# [7507 7410]
# [14917]
# 0
# <built-in function len>

# %% [markdown]
# #### Visualization of y_test and y_pred

# %%
for pos, ((key, y_pred), xy) in enumerate(zip(y_pred_dict.items(),xy_data.values())):  
    step = 100 
    y_test_ds = xy['y_test'][::step] #downsampled to 100 steps
    y_pred_ds = y_pred[::step]

    #plt.subplot(7,1,pos+1)
    plt.figure(figsize=(10,3))
    plt.plot(y_test_ds, color = "green", label = "Test")
    plt.plot(y_pred_ds, color = "blue", label = "Pred")
    plt.title(key)
    plt.tight_layout()
    plt.legend()

plt.show()

# %%
plt.figure(figsize=(14, 16))

for pos, ((key, y_pred), xy) in enumerate (zip(y_pred_dict.items(), xy_data.values())):
    test_counts = np.bincount(xy['y_test'])
    pred_counts = np.bincount(y_pred)

    # Plotting histograms using plt directly
    plt.subplot(4,2,pos+1)
    # Plot test data histogram
    plt.hist(xy['y_test'], bins=[-0.5, 0.5, 1.5], alpha=0.5, color='green', label='Test')

    # Plot pred data histogram
    plt.hist(y_pred, bins=[-0.5, 0.5, 1.5], alpha=0.5, color='blue', label='Pred')

    # Customize plot
    plt.xticks([0, 1], ['0', '1'])
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title(f'Comparison of 0s and 1s between Test and Pred for {key}')
    plt.tight_layout()
    plt.legend()
    

plt.show()

# %% [markdown]
# ## Metrics
#
# Evaluate performance with accuracy, f1_score, precision and recall

# %%
metrics_dict = {}

for xy, (key, y_pred) in zip(xy_data.values(), y_pred_dict.items()):
    
    metrics = calculate_metrics(xy['y_test'], y_pred)
    metrics_dict[key] = metrics
    print(f"{key}: ", metrics)
# Out:
# EUR_USD:  {'accuracy': 0.505529861250754, 'f1_score': 0.0543520061530573, 'precision': 0.5463917525773195, 'recall': 0.028598408201807635}
# USD_JPY:  {'accuracy': 0.5078758629934982, 'f1_score': 0.6736308677098151, 'precision': 0.50794395655963, 'recall': 0.9997361129436602}
# AUD_USD:  {'accuracy': 0.5036868212897171, 'f1_score': 0.0029625639644492324, 'precision': 0.4583333333333333, 'recall': 0.0014860848419346122}
# GBP_USD:  {'accuracy': 0.5047925464173202, 'f1_score': 0.12733286085518544, 'precision': 0.5294695481335953, 'recall': 0.07236842105263158}
# NZD_USD:  {'accuracy': 0.5130679533574588, 'f1_score': 0.08649735981895901, 'precision': 0.5212121212121212, 'recall': 0.047162051000822595}
# USD_CAD:  {'accuracy': 0.5067372796138634, 'f1_score': 0.0013572204125950054, 'precision': 0.45454545454545453, 'recall': 0.0006796248470844094}
# USD_CHF:  {'accuracy': 0.50325132399276, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0}
# C:\Users\Jun San\anaconda3\envs\test_env_gpu\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ##### Metric Bar Chart

# %%
all_metrics = list(next(iter(metrics_dict.values())).keys())

num_models = len(metrics_dict)
bar_width = 0.12
index = np.arange(len(all_metrics))

plt.figure(figsize=(15, 6))
colors = plt.get_cmap('tab20b').colors

for i, (key, metrics) in enumerate(metrics_dict.items()):
    values = [metrics[metric] for metric in all_metrics]
    plt.bar(index + i * bar_width, values, bar_width, label=key, color=colors[i])
    
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Model Performance Metrics Comparison')
plt.xticks(index + bar_width * (num_models - 1) / 2, all_metrics)
plt.ylim(0, 1.0)
plt.legend()
plt.grid(True, axis='y', linestyle='--', linewidth=0.35, color='black')

plt.show()

# %% [markdown]
# #### Reciever Operating Characteristic Curve

# %%
from sklearn.metrics import roc_curve, auc
y_probs = xy_data.items()
y_pred_dict_prob

plt.figure(figsize=(8, 6))
for i, ((key, xy), y_prob) in enumerate(zip(xy_data.items(), y_pred_dict_prob.values())):
    fpr, tpr, thresholds = roc_curve(xy['y_test'], y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=colors[i], lw=0.8, label=f'{key} (AUC = {roc_auc:.3f})')
    plt.plot([0, 1], [0, 1], color='red', linestyle='--', linewidth=0.25)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
plt.show()

# %% [markdown]
# ##### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

for (title, y_pred), xy in zip(y_pred_dict.items(), xy_data.values()):
    print(title)
    cm = confusion_matrix(xy['y_test'], y_pred)
    tn, fp, fn, tp = cm.ravel()
    print(f'True Negatives: {tn}, False Positives: {fp}, False Negatives: {fn}, True Positives: {tp}')
# Out:
# EUR_USD
# True Negatives: 7330, False Positives: 176, False Negatives: 7201, True Positives: 212
# USD_JPY
# True Negatives: 0, False Positives: 7340, False Negatives: 2, True Positives: 7577
# AUD_USD
# True Negatives: 7503, False Positives: 13, False Negatives: 7391, True Positives: 11
# GBP_USD
# True Negatives: 6992, False Positives: 479, False Negatives: 6909, True Positives: 539
# NZD_USD
# True Negatives: 7312, False Positives: 316, False Negatives: 6950, True Positives: 344
# USD_CAD
# True Negatives: 7554, False Positives: 6, False Negatives: 7352, True Positives: 5
# USD_CHF
# True Negatives: 7507, False Positives: 0, False Negatives: 7410, True Positives: 0

# %% [markdown]
# ## Save results

# %%
#Save results to csv
model_type = 'CNN-SRNN'

for key, metrics in metrics_dict.items():
    metrics_df = pd.DataFrame([metrics])
    save_metrics_to_csv(metrics_df, model_type, f'{key}')

# %% [markdown]
# End of section
